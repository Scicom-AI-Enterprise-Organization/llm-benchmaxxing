# %% [markdown]
# # Parallel Benchmarking with Multiprocessing
#
# Run multiple benchmarks in parallel on separate RunPod pods.
#
# ## Setup
#
# Export your RunPod API key before running:
# ```bash
# export RUNPOD_API_KEY="rpa_xxxxx"
# ```

# %%
pip install "git+https://github.com/Scicom-AI-Enterprise-Organization/pyremote"
# Out:
# /Users/ariff.a/Documents/GitHub/llm-benchmaxxing/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from multiprocessing import Pool

import benchmaxxing
from benchmaxxing.runpod import run_benchmark  # Multiprocessing-compatible function

# Set API key
os.environ["RUNPOD_API_KEY"] = ""

print(f"Version: {benchmaxxing.__version__}")
print(f"API Key set: {'Yes' if os.environ.get('RUNPOD_API_KEY') else 'No'}")
# Out:
# Version: 0.3.0
# API Key set: Yes

# %%
# Config files to run in parallel (each on a separate pod)
configs = [
    "6_config_1.yaml",  # 1x GPU
    "6_config_2.yaml",  # 2x GPU
]

# %%
# Run all configs in parallel using multiprocessing
with Pool(processes=len(configs)) as pool:
    results = pool.map(run_benchmark, configs)

# Print results
for r in results:
    print(f"{r['config']}: {r.get('result', r.get('error'))}")
# Out:
# ================================================================
# STEP 1: DEPLOYING RUNPOD POD
# ================================================================
#
# ================================================================
# STEP 1: DEPLOYING RUNPOD POD
# ================================================================
# Using spot instance with minimum bid: $0.82/GPU/hour
# Using spot instance with minimum bid: $0.82/GPU/hour
# Pod created: k56jxlftsvagms
# Pod created: m23tsn00ov9m55
# Pod ready!:   5%|▌         | 3/60 [00:39<12:26, 13.09s/it]
# ✓ Done!
#   SSH: ssh root@38.128.233.55 -p 48180 -i ~/.ssh/id_ed25519
#
# Pod deployed: m23tsn00ov9m55
# Pod name: benchmaxxing_mp_1xa100pcie_1_unittest
# SSH: ssh root@38.128.233.55 -p 48180 -i ~/.ssh/id_ed25519
#
# ================================================================
# STEP 2: RUNNING BENCHMARKS
# ================================================================
# Connecting to remote server: root@38.128.233.55:48180
# Using SSH key: /Users/ariff.a/.ssh/id_ed25519
# UV environment: ~/.benchmark-venv (Python 3.11)
# Dependencies: ['pyyaml', 'requests', 'vllm', 'huggingface_hub']
# Pod ready!:   7%|▋         | 4/60 [00:47<11:00, 11.79s/it]
# ✓ Done!
#   SSH: ssh root@38.128.233.207 -p 33029 -i ~/.ssh/id_ed25519
#
# Pod deployed: k56jxlftsvagms
# Pod name: benchmaxxing_mp_1xa100pcie_2_unittest
# SSH: ssh root@38.128.233.207 -p 33029 -i ~/.ssh/id_ed25519
#
# ================================================================
# STEP 2: RUNNING BENCHMARKS
# ================================================================
# Connecting to remote server: root@38.128.233.207:33029
# Using SSH key: /Users/ariff.a/.ssh/id_ed25519
# UV environment: ~/.benchmark-venv (Python 3.11)
# Dependencies: ['pyyaml', 'requests', 'vllm', 'huggingface_hub']
#
#
# ================================================================
# RUN: benchmaxxing_mp_1xa100pcie_2_unittest_run_1 | TP=1 DP=1 PP=1
# ================================================================
# Starting vLLM server: vllm serve meta-llama/Llama-3.1-8B-Instruct --port 8000 --tensor-parallel-size 1 --pipeline-parallel-size 1 --gpu-memory-utilization 0.9 --disable-log-requests
# Waiting for server at http://localhost:8000/health...
# Health check attempt 1...
# (APIServer pid=413) INFO 01-27 12:50:29 [api_server.py:1272] vLLM API server version 0.14.1
# (APIServer pid=413) INFO 01-27 12:50:29 [utils.py:263] non-default args: {'model_tag': 'meta-llama/Llama-3.1-8B-Instruct', 'model': 'meta-llama/Llama-3.1-8B-Instruct'}
# config.json: 100%|█████████████████████████████| 855/855 [00:00<00:00, 3.43MB/s]
#
# ================================================================
# RUN: benchmaxxing_mp_1xa100pcie_1_unittest_run_1 | TP=1 DP=1 PP=1
# ================================================================
# Starting vLLM server: vllm serve meta-llama/Llama-3.1-8B-Instruct --port 8000 --tensor-parallel-size 1 --pipeline-parallel-size 1 --gpu-memory-utilization 0.9 --disable-log-requests
# Waiting for server at http://localhost:8000/health...
# Health check attempt 1...
# (APIServer pid=413) INFO 01-27 12:50:37 [model.py:530] Resolved architecture: LlamaForCausalLM
# (APIServer pid=413) INFO 01-27 12:50:37 [model.py:1545] Using max model len 131072
# (APIServer pid=413) INFO 01-27 12:50:38 [scheduler.py:229] Chunked prefill is enabled with max_num_batched_tokens=2048.
# (APIServer pid=413) INFO 01-27 12:50:38 [vllm.py:630] Asynchronous scheduling is enabled.
# (APIServer pid=413) INFO 01-27 12:50:38 [vllm.py:637] Disabling NCCL for DP synchronization when using async scheduling.
# tokenizer_config.json: 100%|███████████████| 55.4k/55.4k [00:00<00:00, 12.1MB/s]
# tokenizer.json: 100%|██████████████████████| 9.09M/9.09M [00:00<00:00, 35.1MB/s]
# special_tokens_map.json: 100%|█████████████████| 296/296 [00:00<00:00, 2.26MB/s]
# generation_config.json: 100%|██████████████████| 184/184 [00:00<00:00, 1.47MB/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:50:48 [core.py:97] Initializing a V1 LLM engine (v0.14.1) with config: model='meta-llama/Llama-3.1-8B-Instruct', speculative_config=None, tokenizer='meta-llama/Llama-3.1-8B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=meta-llama/Llama-3.1-8B-Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'eliminate_noops': True, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': True}, 'local_cache_dir': None}
# (APIServer pid=349) INFO 01-27 12:50:48 [api_server.py:1272] vLLM API server version 0.14.1
# (APIServer pid=349) INFO 01-27 12:50:48 [utils.py:263] non-default args: {'model_tag': 'meta-llama/Llama-3.1-8B-Instruct', 'model': 'meta-llama/Llama-3.1-8B-Instruct'}
# (EngineCore_DP0 pid=679) INFO 01-27 12:50:48 [parallel_state.py:1214] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.23.0.2:46809 backend=nccl
# (EngineCore_DP0 pid=679) INFO 01-27 12:50:48 [parallel_state.py:1425] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A
# config.json: 100%|█████████████████████████████| 855/855 [00:00<00:00, 9.41MB/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:50:49 [gpu_model_runner.py:3808] Starting to load model meta-llama/Llama-3.1-8B-Instruct...
# (APIServer pid=349) INFO 01-27 12:50:57 [model.py:530] Resolved architecture: LlamaForCausalLM
# (APIServer pid=349) INFO 01-27 12:50:57 [model.py:1545] Using max model len 131072
# (APIServer pid=349) INFO 01-27 12:50:57 [scheduler.py:229] Chunked prefill is enabled with max_num_batched_tokens=2048.
# (APIServer pid=349) INFO 01-27 12:50:57 [vllm.py:630] Asynchronous scheduling is enabled.
# (APIServer pid=349) INFO 01-27 12:50:57 [vllm.py:637] Disabling NCCL for DP synchronization when using async scheduling.
# tokenizer_config.json: 100%|███████████████| 55.4k/55.4k [00:00<00:00, 50.9MB/s]
# tokenizer.json: 100%|██████████████████████| 9.09M/9.09M [00:00<00:00, 36.5MB/s]
# special_tokens_map.json: 100%|█████████████████| 296/296 [00:00<00:00, 3.68MB/s]
# generation_config.json: 100%|██████████████████| 184/184 [00:00<00:00, 1.96MB/s]
# Health check attempt 11...
# (EngineCore_DP0 pid=615) INFO 01-27 12:51:07 [core.py:97] Initializing a V1 LLM engine (v0.14.1) with config: model='meta-llama/Llama-3.1-8B-Instruct', speculative_config=None, tokenizer='meta-llama/Llama-3.1-8B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=meta-llama/Llama-3.1-8B-Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'eliminate_noops': True, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': True}, 'local_cache_dir': None}
# (EngineCore_DP0 pid=615) INFO 01-27 12:51:08 [parallel_state.py:1214] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.26.0.2:56869 backend=nccl
# (EngineCore_DP0 pid=615) INFO 01-27 12:51:08 [parallel_state.py:1425] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A
# (EngineCore_DP0 pid=615) INFO 01-27 12:51:09 [gpu_model_runner.py:3808] Starting to load model meta-llama/Llama-3.1-8B-Instruct...
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:11 [cuda.py:351] Using FLASH_ATTN attention backend out of potential backends: ('FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION')
# model.safetensors.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 70.9MB/s]
# model-00004-of-00004.safetensors:   0%|             | 0.00/1.17G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:   0%|             | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   1%|    | 67.1M/4.98G [00:01<01:50, 44.2MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:   6%|▏   | 67.0M/1.17G [00:01<00:27, 40.6MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:  11%|▌    | 134M/1.17G [00:02<00:13, 75.0MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   1%|    | 67.1M/5.00G [00:02<02:40, 30.7MB/s]
# model-00004-of-00004.safetensors:  18%|▉    | 216M/1.17G [00:02<00:10, 92.8MB/s]
# model-00001-of-00004.safetensors:   4%|▏    | 202M/4.98G [00:02<00:59, 80.6MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   3%|▏    | 134M/5.00G [00:03<02:13, 36.6MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:  25%|█▏   | 291M/1.17G [00:03<00:11, 78.7MB/s]
# model-00001-of-00004.safetensors:   7%|▎    | 336M/4.98G [00:03<00:46, 99.9MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   5%|▎    | 268M/5.00G [00:03<00:52, 89.9MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:  35%|██    | 403M/1.17G [00:04<00:07, 104MB/s]
# model-00001-of-00004.safetensors:   8%|▍    | 402M/4.98G [00:04<00:50, 91.1MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   7%|▎    | 335M/5.00G [00:04<00:57, 80.8MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:  40%|██▍   | 470M/1.17G [00:04<00:05, 129MB/s]
# model-00004-of-00004.safetensors:  46%|██▊   | 537M/1.17G [00:05<00:04, 153MB/s]
# model-00001-of-00004.safetensors:  12%|▋     | 580M/4.98G [00:05<00:28, 155MB/s]
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors:  52%|███   | 604M/1.17G [00:05<00:03, 175MB/s]
# model-00001-of-00004.safetensors:  13%|▊     | 648M/4.98G [00:05<00:23, 182MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:  10%|▌     | 472M/4.92G [00:05<00:37, 119MB/s]
# model-00001-of-00004.safetensors:  16%|▉     | 782M/4.98G [00:06<00:19, 215MB/s]
# model-00001-of-00004.safetensors:  18%|█     | 872M/4.98G [00:06<00:15, 265MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:   9%|▍    | 469M/5.00G [00:06<00:52, 86.9MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:  11%|▋     | 539M/4.92G [00:06<00:36, 120MB/s]
# model-00001-of-00004.safetensors:  20%|█    | 1.01G/4.98G [00:06<00:15, 256MB/s]
# model-00004-of-00004.safetensors:  55%|██▋  | 640M/1.17G [00:07<00:08, 63.0MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:  11%|▌    | 536M/5.00G [00:07<01:00, 73.4MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:
/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:  93%|████▋| 4.58G/4.92G [00:22<00:01, 269MB/s]
# (EngineCore_DP0 pid=679)
# model-00002-of-00004.safetensors:  93%|███▋| 4.66G/5.00G [00:22<00:00, 1.10GB/s]
# model-00001-of-00004.safetensors:  92%|████▌| 4.57G/4.98G [00:22<00:01, 229MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors: 100%|████| 1.17G/1.17G [00:22<00:00, 32.3MB/s]
# (EngineCore_DP0 pid=679)
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:  96%|████▊| 4.71G/4.92G [00:22<00:00, 333MB/s]
# (EngineCore_DP0 pid=679)
# model-00004-of-00004.safetensors: 100%|████| 1.17G/1.17G [00:22<00:00, 51.4MB/s]
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors: 100%|█████| 4.92G/4.92G [00:22<00:00, 216MB/s]
# model-00002-of-00004.safetensors: 100%|█████| 5.00G/5.00G [00:22<00:00, 219MB/s]
# model-00004-of-00004.safetensors:   0%|             | 0.00/1.17G [00:00<?, ?B/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=679)
# model-00001-of-00004.safetensors: 100%|█████| 4.98G/4.98G [00:22<00:00, 218MB/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:34 [weight_utils.py:510] Time spent downloading weights for meta-llama/Llama-3.1-8B-Instruct: 23.165206 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:00<00:00,  5.07it/s]
# model-00004-of-00004.safetensors:   1%|    | 8.22M/1.17G [00:00<01:07, 17.3MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:   0%|   | 840k/4.92G [00:00<1:10:15, 1.17MB/s]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:01<00:01,  1.61it/s]
# model-00004-of-00004.safetensors:   1%|    | 16.8M/1.17G [00:01<01:39, 11.6MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:   1%|    | 67.9M/4.92G [00:01<01:52, 42.9MB/s]
# model-00002-of-00004.safetensors:   1%|    | 67.8M/5.00G [00:01<02:08, 38.2MB/s]
# (EngineCore_DP0 pid=615)
# model-00004-of-00004.safetensors:  10%|▌    | 117M/1.17G [00:02<00:16, 64.6MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:02<00:00,  1.17it/s]
# model-00003-of-00004.safetensors:   3%|▏    | 135M/4.92G [00:02<01:05, 72.7MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:   2%|    | 90.1M/4.98G [00:02<02:08, 38.0MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:   4%|▏     | 202M/4.92G [00:02<00:45, 104MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 135M/5.00G [00:02<01:21, 59.5MB/s]
# model-00002-of-00004.safetensors:   4%|▏     | 202M/5.00G [00:02<00:47, 101MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:   7%|▍     | 336M/4.92G [00:02<00:24, 187MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:  10%|▌     | 470M/4.92G [00:03<00:16, 275MB/s]
# model-00002-of-00004.safetensors:   7%|▍     | 338M/5.00G [00:03<00:27, 169MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.13it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.26it/s]
# (EngineCore_DP0 pid=679)
# model-00003-of-00004.safetensors:  11%|▋     | 537M/4.92G [00:03<00:15, 285MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:   3%|▏    | 157M/4.98G [00:03<01:29, 54.1MB/s]
# model-00002-of-00004.safetensors:   8%|▍     | 405M/5.00G [00:03<00:21, 209MB/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:38 [default_loader.py:291] Loading weights took 3.39 seconds
# model-00002-of-00004.safetensors:   9%|▌     | 472M/5.00G [00:03<00:18, 251MB/s]
# model-00002-of-00004.safetensors:  12%|▋     | 606M/5.00G [00:03<00:12, 344MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:   4%|▏    | 202M/4.98G [00:03<01:20, 59.0MB/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:51
B/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:  88%|████▍| 4.37G/4.98G [00:17<00:01, 441MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00004-of-00004.safetensors:  27%|█▎   | 319M/1.17G [00:17<00:37, 22.6MB/s]
# model-00002-of-00004.safetensors:  96%|████▊| 4.80G/5.00G [00:17<00:01, 143MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:  89%|████▍| 4.44G/4.98G [00:17<00:01, 386MB/s]
# model-00004-of-00004.safetensors:  37%|█▊   | 431M/1.17G [00:17<00:17, 43.3MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:  91%|████▌| 4.51G/4.98G [00:17<00:01, 341MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:  90%|████▌| 4.45G/4.92G [00:17<00:02, 222MB/s]
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors:  93%|████▋| 4.64G/4.98G [00:17<00:00, 442MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00004-of-00004.safetensors:  48%|██▍  | 565M/1.17G [00:18<00:07, 81.1MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00004-of-00004.safetensors:  60%|███▌  | 699M/1.17G [00:18<00:03, 133MB/s]
# (EngineCore_DP0 pid=615)
# model-00004-of-00004.safetensors:  66%|███▉  | 766M/1.17G [00:18<00:02, 161MB/s]
# model-00002-of-00004.safetensors:  99%|████▉| 4.93G/5.00G [00:18<00:00, 147MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors:  97%|████▊| 4.78G/4.92G [00:18<00:00, 454MB/s]
# (EngineCore_DP0 pid=615)
# model-00003-of-00004.safetensors: 100%|█████| 4.92G/4.92G [00:18<00:00, 268MB/s]
# (EngineCore_DP0 pid=615)
# (EngineCore_DP0 pid=615)
# model-00001-of-00004.safetensors: 100%|█████| 4.98G/4.98G [00:18<00:00, 270MB/s]
# model-00004-of-00004.safetensors: 100%|████| 1.17G/1.17G [00:18<00:00, 63.0MB/s]
# (EngineCore_DP0 pid=615)
# model-00002-of-00004.safetensors: 100%|█████| 5.00G/5.00G [00:18<00:00, 269MB/s]
# (EngineCore_DP0 pid=615) INFO 01-27 12:51:53 [weight_utils.py:510] Time spent downloading weights for meta-llama/Llama-3.1-8B-Instruct: 18.928895 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:54 [backends.py:278] Compiling a graph for compile range (1, 2048) takes 7.34 s
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:54 [monitor.py:34] torch.compile takes 11.26 s in total
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:01<00:03,  1.15s/it]
# (EngineCore_DP0 pid=679) INFO 01-27 12:51:55 [gpu_worker.py:358] Available KV cache memory: 55.11 GiB
# ...
# Namespace(subparser='bench', bench_type='serve', dispatch_function=<function BenchmarkServingSubcommand.cmd at 0x794ed64ab1a0>, seed=0, num_prompts=100, dataset_name='random', no_stream=False, dataset_path=None, no_oversample=False, skip_chat_template=False, disable_shuffle=False, custom_output_len=256, spec_bench_output_len=256, spec_bench_category=None, sonnet_input_len=550, sonnet_output_len=150, sonnet_prefix_len=200, sharegpt_output_len=None, blazedit_min_distance=0.0, blazedit_max_distance=1.0, random_input_len=1024, random_output_len=128, random_range_ratio=0.0, random_prefix_len=0, random_batch_size=1, no_reranker=False, random_mm_base_items_per_request=1, random_mm_num_mm_items_range_ratio=0.0, random_mm_limit_mm_per_prompt={'image': 255, 'video': 1}, random_mm_bucket_config={(256, 256, 1): 0.5, (720, 1280, 1): 0.5, (720, 1280, 16): 0.0}, hf_subset=None, hf_split=None, hf_name=None, hf_output_len=None, prefix_repetition_prefix_len=256, prefix_repetition_suffix_len=256, prefix_repetition_num_prefixes=10, prefix_repetition_output_len=128, label=None, backend='vllm', base_url='http://localhost:8000', host='127.0.0.1', port=8000, endpoint='/v1/completions', header=None, max_concurrency=100, model='meta-llama/Llama-3.1-8B-Instruct', input_len=None, output_len=None, tokenizer=None, tokenizer_mode='auto', use_beam_search=False, logprobs=None, request_rate=inf, burstiness=1.0, trust_remote_code=False, disable_tqdm=False, num_warmups=0, profile=False, save_result=True, save_detailed=False, append_result=False, metadata=None, result_dir='./benchmark_results', result_filename='benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.json', ignore_eos=True, percentile_metrics='ttft,tpot,itl,e2el', metric_percentiles='99', goodput=None, request_id_prefix='bench-109a318c-', top_p=None, top_k=None, min_p=None, temperature=None, frequency_penalty=None, presence_penalty=None, repetition_penalty=None, served_model_name=None, lora_modules=None, ramp_up_strategy=None, ramp_up_start_rps=None, ramp_up_end_rps=None, ready_check_timeout_sec=0, extra_body=None)
# INFO 01-27 12:54:33 [datasets.py:612] Sampling input_len from [1023, 1023] and output_len from [128, 128]
# (APIServer pid=2144) INFO:     127.0.0.1:44380 - "GET /metrics HTTP/1.1" 200 OK
# Starting initial single prompt test run...
# Skipping endpoint ready check.
# Starting main benchmark run...
# Traffic request rate: inf
# Burstiness factor: 1.0 (Poisson process)
# Maximum request concurrency: 100
#
# (APIServer pid=2144) INFO:     127.0.0.1:44380 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44392 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44404 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44418 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44432 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44440 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44442 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44456 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44464 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44474 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44486 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44500 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44510 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44522 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44534 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44546 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44548 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44558 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44568 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44578 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44584 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44590 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44606 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44614 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44622 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44632 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44636 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44650 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44658 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44660 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44676 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44692 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44704 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44712 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44724 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44736 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44752 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44760 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44772 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44782 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44796 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44802 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44818 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44828 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44842 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44848 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44852 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44864 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44866 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44882 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44886 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44894 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44898 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44910 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44918 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44934 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44940 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44942 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44946 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44950 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44960 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44966 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44980 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44990 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:44994 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45010 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45016 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45024 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45038 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45052 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45066 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45072 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45080 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45082 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45090 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45092 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45108 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45120 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45134 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45142 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45144 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45158 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45164 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45180 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45182 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45196 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45212 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45224 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45240 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45246 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45256 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45258 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45274 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45282 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45284 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45294 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45296 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45300 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45314 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO:     127.0.0.1:45318 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2144) INFO 01-27 12:54:35 [loggers.py:257] Engine 000: Avg prompt throughput: 10337.8 tokens/s, Avg generation throughput: 977.3 tokens/s, Running: 100 reqs, Waiting: 0 reqs, GPU KV cache usage: 10.5%, Prefix cache hit rate: 49.2%
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|          | 1/100 [00:02<04:16,  2.59s/it]
#   2%|▏         | 2/100 [00:02<01:59,  1.22s/it]
# 100%|██████████| 100/100 [00:02<00:00, 33.86it/s]
# (APIServer pid=2144) INFO:     127.0.0.1:44380 - "GET /metrics HTTP/1.1" 200 OK
# tip: install termplotlib and gnuplot to plot the metrics
# ============ Serving Benchmark Result ============
# Successful requests:                     100
# Failed requests:                         0
# Maximum request concurrency:             100
# Benchmark duration (s):                  2.95
# Total input tokens:                      102300
# Total generated tokens:                  12800
# Request throughput (req/s):              33.85
# Output token throughput (tok/s):         4333.28
# Peak output token throughput (tok/s):    4903.00
# Peak concurrent requests:                100.00
# Total token throughput (tok/s):          38965.70
# ---------------Time to First Token----------------
# Mean TTFT (ms):                          304.42
# Median TTFT (ms):                        300.56
# P99 TTFT (ms):                           384.79
# -----Time per Output Token (excl. 1st token)------
# Mean TPOT (ms):                          20.51
# Median TPOT (ms):                        20.60
# P99 TPOT (ms):                           20.94
# ---------------Inter-token Latency----------------
# Mean ITL (ms):                           20.52
# Median ITL (ms):                         20.14
# P99 ITL (ms):                            41.17
# ----------------End-to-end Latency----------------
# Mean E2EL (ms):                          2909.27
# Median E2EL (ms):                        2917.30
# P99 E2EL (ms):                           2933.37
# ==================================================
# Saved log: ./benchmark_results/benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.txt
# Stopping vLLM server on port 8000...
# (APIServer pid=2144) INFO 01-27 12:54:37 [launcher.py:110] Shutting down FastAPI HTTP server.
# (Worker_TP0 pid=2540) INFO 01-27 12:54:37 [multiproc_executor.py:707] Parent process exited, terminating worker
# (Worker_TP1 pid=2541) INFO 01-27 12:54:37 [multiproc_executor.py:707] Parent process exited, terminating worker
# (APIServer pid=2144) INFO:     Shutting down
# (APIServer pid=2144) INFO:     Waiting for application shutdown.
# (APIServer pid=2144) INFO:     Application shutdown complete.
#
# ================================================================
# BENCHMARK COMPLETED!
# ================================================================
#
# ================================================================
# Remote execution completed!
# ================================================================
#
# ================================================================
# STEP 3: DOWNLOADING RESULTS
# ================================================================
# Connecting to 38.128.233.207:33029...
# Downloading results from ./benchmark_results to benchmark_results/...
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.json
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.json
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.json
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C50_P100_O128.json
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.txt
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.txt
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.txt
#   Downloaded: benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C50_P100_O128.txt
# Results saved to benchmark_results/
#
# ================================================================
# STEP 4: CLEANING UP POD
# ================================================================
#
# Deleting pod: k56jxlftsvagms
# Pod deleted: {'status': 'deleted', 'id': 'k56jxlftsvagms', 'name': None}
#
# ================================================================
# END-TO-END BENCHMARK COMPLETED!
# ================================================================
# 6_config_1.yaml: {'status': 'success', 'gpu_type': 'NVIDIA A100 80GB PCIe', 'gpu_count': 1}
# 6_config_2.yaml: {'status': 'success', 'gpu_type': 'NVIDIA A100 80GB PCIe', 'gpu_count': 2}

# %% [markdown]
# ## Check Results

# %%
results_dir = "./benchmark_results"
if os.path.exists(results_dir):
    files = sorted(os.listdir(results_dir))
    print(f"Found {len(files)} result files:")
    for f in files:
        print(f"  {f}")
else:
    print("No results yet")
# Out:
# Found 12 result files:
#   benchmaxxing_mp_1xa100pcie_1_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_1_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.txt
#   benchmaxxing_mp_1xa100pcie_1_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_1_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.txt
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C100_P100_O128.txt
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP1_DP1_CTX1024_C50_P100_O128.txt
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C100_P100_O128.txt
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C50_P100_O128.json
#   benchmaxxing_mp_1xa100pcie_2_unittest_run_1_TP2_DP1_CTX1024_C50_P100_O128.txt
