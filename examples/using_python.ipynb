# %%
import benchmaq.vllm.bench as vllm_bench
import benchmaq.runpod.bench as runpod_bench

# %%
# Run local benchmark
vllm_bench.from_yaml("4_example_local_config.yaml")

# %%
# Run remote benchmark (via SSH)
vllm_bench.from_yaml("5_example_remote_config.yaml")

# %%
# Run RunPod benchmark (deploy -> bench -> delete)
runpod_bench.from_yaml("6_example_runpod_config.yaml")
